# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Settings
units = 'metric'
url = f'http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={units}&q='

# For sets and breaks
count = 1
setNum = 1

# Storing data
name = []
cloud = []
country = []
date = []
humid = []
lat = []
lon = []
maxTemp = []
wind = []

# Starting iteration
print('''Beginning Data Retrieval
-----------------------------''')

for city in cities:
    data = requests.get(url + city).json()

    try:
        name.append(data['name'])
        cloud.append(data['clouds']['all'])
        country.append(data['sys']['country'])
        date.append(data['dt'])
        humid.append(data['main']['humidity'])
        lat.append(data['coord']['lat'])
        lon.append(data['coord']['lon'])
        maxTemp.append(data['main']['temp_max'])
        wind.append(data['wind']['speed'])
        print(f'Processing Record {count} of Set {setNum} | {city}')
        count = count + 1
            
    except:
        print('City not found. Skipping...')
    
    # Putting a break between each set to avoid overhaul
    if count == 51:
        count = 1
        setNum += 1
        print('------ break for 10 seconds ------')
        time.sleep(10)

print('''-----------------------------
Data Retrieval Complete
-----------------------------''')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khatassy
# Processing Record 2 of Set 1 | zhigansk
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | bredasdorp
# City not found. Skipping...
# Processing Record 6 of Set 1 | hay river
# Processing Record 7 of Set 1 | lazaro cardenas
# Processing Record 8 of Set 1 | antalaha
# Processing Record 9 of Set 1 | norman wells
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | nizhneudinsk
# City not found. Skipping...
# Processing Record 16 of Set 1 | requena
# City not found. Skipping...
# Processing Record 17 of Set 1 | tasiilaq
# Processing Record 18 of Set 1 | rio gallegos
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 1 | avarua
# City not found. Skipping...
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | okhotsk
# Processing Record 22 of Set 1 | pangnirtung
# Processing Record 23 of Set 1 | palmer
# Processing Record 24 of Set 1 | leningradskiy
# Processing Record 25 of Set 1 | genhe
# City not found. Skipping...
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | cockburn town
# City not found. Skipping...
# Processing Record 28 of Set 1 | sao filipe
# Processing Record 29 of Set 1 | zapolyarnyy
# Processing Record 30 of Set 1 | ponta do sol
# Processing Record 31 of Set 1 | mahibadhoo
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | ixtapa
# Processing Record 34 of Set 1 | souillac
# Processing Record 35 of Set 1 | newport
# Processing Record 36 of Set 1 | carnarvon
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | hermanus
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of Set 1 | manavalakurichi
# Processing Record 40 of Set 1 | lasa
# Processing Record 41 of Set 1 | kaitangata
# Processing Record 42 of Set 1 | kavieng
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | iracoubo
# Processing Record 45 of Set 1 | chuy
# Processing Record 46 of Set 1 | tuatapere
# Processing Record 47 of Set 1 | malanje
# Processing Record 48 of Set 1 | mugur-aksy
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | hithadhoo
# ------ break for 10 seconds ------
# Processing Record 1 of Set 2 | deputatskiy
# Processing Record 2 of Set 2 | biak
# Processing Record 3 of Set 2 | rio grande
# Processing Record 4 of Set 2 | katsuura
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | ulaangom
# Processing Record 7 of Set 2 | saint-philippe
# Processing Record 8 of Set 2 | concarneau
# Processing Record 9 of Set 2 | east london
# Processing Record 10 of Set 2 | ust-tsilma
# Processing Record 11 of Set 2 | muros
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | atar
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | bambous virieux
# Processing Record 17 of Set 2 | kendari
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | moyale
# City not found. Skipping...
# Processing Record 21 of Set 2 | faanui
# Processing Record 22 of Set 2 | mogadishu
# Processing Record 23 of Set 2 | punta arenas
# Processing Record 24 of Set 2 | black river
# Processing Record 25 of Set 2 | laguna
# Processing Record 26 of Set 2 | oiso
# Processing Record 27 of Set 2 | college
# Processing Record 28 of Set 2 | marystown
# Processing Record 29 of Set 2 | penticton
# Processing Record 30 of Set 2 | aklavik
# City not found. Skipping...
# Processing Record 31 of Set 2 | rochegda
# Processing Record 32 of Set 2 | klyuchi
# Processing Record 33 of Set 2 | meulaboh
# City not found. Skipping...
# Processing Record 34 of Set 2 | bethel
# City not found. Skipping...
# Processing Record 35 of Set 2 | tual
# Processing Record 36 of Set 2 | beringovskiy
# Processing Record 37 of Set 2 | vestmannaeyjar
# Processing Record 38 of Set 2 | linxia
# Processing Record 39 of Set 2 | wukari
# Processing Record 40 of Set 2 | butwal
# Processing Record 41 of Set 2 | bonavista
# Processing Record 42 of Set 2 | martil
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | ahipara
# Processing Record 45 of Set 2 | saint anthony
# Processing Record 46 of Set 2 | severo-kurilsk
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | caernarfon
# Processing Record 50 of Set 2 | ouesso
# ------ break for 10 seconds ------
# Processing Record 1 of Set 3 | guerrero negro
# Processing Record 2 of Set 3 | mahenge
# Processing Record 3 of Set 3 | alta floresta
# Processing Record 4 of Set 3 | plouzane
# Processing Record 5 of Set 3 | erzin
# Processing Record 6 of Set 3 | noumea
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 3 | asosa
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | cherskiy
# Processing Record 10 of Set 3 | beaufort
# Processing Record 11 of Set 3 | san patricio
# City not found. Skipping...
# Processing Record 12 of Set 3 | chokurdakh
# Processing Record 13 of Set 3 | thompson
# Processing Record 14 of Set 3 | kavaratti
# Processing Record 15 of Set 3 | daru
# Processing Record 16 of Set 3 | saskylakh
# Processing Record 17 of Set 3 | osinniki
# Processing Record 18 of Set 3 | kruisfontein
# Processing Record 19 of Set 3 | north vanlaiphai
# Processing Record 20 of Set 3 | les cayes
# Processing Record 21 of Set 3 | mahebourg
# Processing Record 22 of Set 3 | suba
# Processing Record 23 of Set 3 | lorengau
# Processing Record 24 of Set 3 | turukhansk
# Processing Record 25 of Set 3 | lebu
# Processing Record 26 of Set 3 | gorontalo
# Processing Record 27 of Set 3 | nikolskoye
# Processing Record 28 of Set 3 | fuyang
# Processing Record 29 of Set 3 | tiksi
# Processing Record 30 of Set 3 | torbay
# Processing Record 31 of Set 3 | dikson
# Processing Record 32 of Set 3 | arraial do cabo
# Processing Record 33 of Set 3 | butaritari
# Processing Record 34 of Set 3 | ancud
# City not found. Skipping...
# Processing Record 35 of Set 3 | mnogovershinnyy
# Processing Record 36 of Set 3 | yellowknife
# Processing Record 37 of Set 3 | kyzyl-suu
# Processing Record 38 of Set 3 | rawson
# Processing Record 39 of Set 3 | atuona
# Processing Record 40 of Set 3 | poum
# Processing Record 41 of Set 3 | vaitape
# City not found. Skipping...
# Processing Record 42 of Set 3 | saldanha
# City not found. Skipping...
# Processing Record 43 of Set 3 | sisimiut
# Processing Record 44 of Set 3 | pisco
# Processing Record 45 of Set 3 | ustyuzhna
# Processing Record 46 of Set 3 | alice springs
# Processing Record 47 of Set 3 | klaksvik
# Processing Record 48 of Set 3 | ilulissat
# Processing Record 49 of Set 3 | tairua
# City not found. Skipping...
# Processing Record 50 of Set 3 | laohekou
# ------ break for 10 seconds ------
# Processing Record 1 of Set 4 | sobolevo
# Processing Record 2 of Set 4 | neuquen
# Processing Record 3 of Set 4 | yar-sale
# Processing Record 4 of Set 4 | roma
# Processing Record 5 of Set 4 | oksfjord
# Processing Record 6 of Set 4 | san andres
# Processing Record 7 of Set 4 | kijang
# Processing Record 8 of Set 4 | jinchang
# Processing Record 9 of Set 4 | timmins
# Processing Record 10 of Set 4 | pergamino
# City not found. Skipping...
# Processing Record 11 of Set 4 | kalmunai
# Processing Record 12 of Set 4 | isiro
# Processing Record 13 of Set 4 | broken hill
# Processing Record 14 of Set 4 | comodoro rivadavia
# Processing Record 15 of Set 4 | loralai
# Processing Record 16 of Set 4 | chapais
# Processing Record 17 of Set 4 | dawlatabad
# Processing Record 18 of Set 4 | avera
# Processing Record 19 of Set 4 | nome
# Processing Record 20 of Set 4 | yerbogachen
# Processing Record 21 of Set 4 | airai
# Processing Record 22 of Set 4 | barrow
# City not found. Skipping...
# Processing Record 23 of Set 4 | husavik
# Processing Record 24 of Set 4 | lompoc
# Processing Record 25 of Set 4 | sao joao da barra
# Processing Record 26 of Set 4 | lizzano
# Processing Record 27 of Set 4 | kolindros
# Processing Record 28 of Set 4 | majalgaon
# Processing Record 29 of Set 4 | vilhena
# Processing Record 30 of Set 4 | coihaique
# Processing Record 31 of Set 4 | gallup
# Processing Record 32 of Set 4 | san quintin
# Processing Record 33 of Set 4 | sonqor
# Processing Record 34 of Set 4 | georgiyevka
# City not found. Skipping...
# Processing Record 35 of Set 4 | faya
# City not found. Skipping...
# Processing Record 36 of Set 4 | peabiru
# Processing Record 37 of Set 4 | flin flon
# Processing Record 38 of Set 4 | kaeo
# City not found. Skipping...
# Processing Record 39 of Set 4 | penzance
# Processing Record 40 of Set 4 | tefe
# Processing Record 41 of Set 4 | luba
# Processing Record 42 of Set 4 | shanhetun
# Processing Record 43 of Set 4 | canmore
# Processing Record 44 of Set 4 | pangody
# Processing Record 45 of Set 4 | vostok
# Processing Record 46 of Set 4 | agadir
# Processing Record 47 of Set 4 | axim
# Processing Record 48 of Set 4 | anloga
# Processing Record 49 of Set 4 | codrington
# Processing Record 50 of Set 4 | polovinnoye
# ------ break for 10 seconds ------
# Processing Record 1 of Set 5 | tuktoyaktuk
# Processing Record 2 of Set 5 | waddan
# Processing Record 3 of Set 5 | nemuro
# Processing Record 4 of Set 5 | ostrovnoy
# City not found. Skipping...
# Processing Record 5 of Set 5 | srednekolymsk
# Processing Record 6 of Set 5 | mirnyy
# Processing Record 7 of Set 5 | matongo
# Processing Record 8 of Set 5 | skjervoy
# Processing Record 9 of Set 5 | vardo
# Processing Record 10 of Set 5 | constitucion
# Processing Record 11 of Set 5 | krasnoufimsk
# Processing Record 12 of Set 5 | wilmington
# Processing Record 13 of Set 5 | vila
# Processing Record 14 of Set 5 | cayenne
# Processing Record 15 of Set 5 | matara
# Processing Record 16 of Set 5 | provideniya
# Processing Record 17 of Set 5 | datong
# Processing Record 18 of Set 5 | montijo
# Processing Record 19 of Set 5 | takoradi
# Processing Record 20 of Set 5 | tiruchchirappalli
# Processing Record 21 of Set 5 | radenci
# Processing Record 22 of Set 5 | paamiut
# Processing Record 23 of Set 5 | kahului
# City not found. Skipping...
# Processing Record 24 of Set 5 | upernavik
# Processing Record 25 of Set 5 | luderitz
# Processing Record 26 of Set 5 | sioux lookout
# Processing Record 27 of Set 5 | todos santos
# Processing Record 28 of Set 5 | apata
# Processing Record 29 of Set 5 | hami
# Processing Record 30 of Set 5 | mango
# City not found. Skipping...
# Processing Record 31 of Set 5 | margate
# Processing Record 32 of Set 5 | bambanglipuro
# Processing Record 33 of Set 5 | hambantota
# Processing Record 34 of Set 5 | santa cruz de tenerife
# Processing Record 35 of Set 5 | goderich
# Processing Record 36 of Set 5 | nhlangano
# Processing Record 37 of Set 5 | namatanai
# Processing Record 38 of Set 5 | riviere-au-renard
# Processing Record 39 of Set 5 | selizharovo
# Processing Record 40 of Set 5 | takapau
# City not found. Skipping...
# Processing Record 41 of Set 5 | tessalit
# Processing Record 42 of Set 5 | hasaki
# Processing Record 43 of Set 5 | praxedis guerrero
# Processing Record 44 of Set 5 | cabo san lucas
# Processing Record 45 of Set 5 | lingao
# Processing Record 46 of Set 5 | lahaina
# Processing Record 47 of Set 5 | yarkovo
# Processing Record 48 of Set 5 | brae
# City not found. Skipping...
# Processing Record 49 of Set 5 | praya
# Processing Record 50 of Set 5 | los llanos de aridane
# ------ break for 10 seconds ------
# Processing Record 1 of Set 6 | longyearbyen
# Processing Record 2 of Set 6 | peniche
# Processing Record 3 of Set 6 | port stanley
# Processing Record 4 of Set 6 | waingapu
# City not found. Skipping...
# Processing Record 5 of Set 6 | lagoa
# Processing Record 6 of Set 6 | myitkyina
# Processing Record 7 of Set 6 | port hardy
# Processing Record 8 of Set 6 | dunedin
# Processing Record 9 of Set 6 | kenora
# Processing Record 10 of Set 6 | rota
# Processing Record 11 of Set 6 | jinxiang
# Processing Record 12 of Set 6 | cerrito
# Processing Record 13 of Set 6 | sobinka
# Processing Record 14 of Set 6 | oss
# Processing Record 15 of Set 6 | esperance
# Processing Record 16 of Set 6 | valverde del camino
# City not found. Skipping...
# Processing Record 17 of Set 6 | pustoshka
# Processing Record 18 of Set 6 | moindou
# Processing Record 19 of Set 6 | sitka
# Processing Record 20 of Set 6 | port lincoln
# Processing Record 21 of Set 6 | vredendal
# Processing Record 22 of Set 6 | nchelenge
# Processing Record 23 of Set 6 | lewistown
# Processing Record 24 of Set 6 | geraldton
# Processing Record 25 of Set 6 | porto walter
# Processing Record 26 of Set 6 | boguchany
# Processing Record 27 of Set 6 | tilichiki
# Processing Record 28 of Set 6 | qaanaaq
# Processing Record 29 of Set 6 | victoria
# Processing Record 30 of Set 6 | lavrentiya
# Processing Record 31 of Set 6 | jackson
# Processing Record 32 of Set 6 | marawi
# Processing Record 33 of Set 6 | bagdarin
# Processing Record 34 of Set 6 | kaseda
# Processing Record 35 of Set 6 | macherla
# Processing Record 36 of Set 6 | rocky mountain house
# City not found. Skipping...
# Processing Record 37 of Set 6 | ginir
# Processing Record 38 of Set 6 | naze
# Processing Record 39 of Set 6 | bereda
# Processing Record 40 of Set 6 | shu
# Processing Record 41 of Set 6 | rieti
# City not found. Skipping...
# Processing Record 42 of Set 6 | narsaq
# Processing Record 43 of Set 6 | kiunga
# Processing Record 44 of Set 6 | takhtamygda
# Processing Record 45 of Set 6 | qingyuan
# Processing Record 46 of Set 6 | cuiluan
# City not found. Skipping...
# Processing Record 47 of Set 6 | melo
# Processing Record 48 of Set 6 | bandrele
# Processing Record 49 of Set 6 | haines junction
# Processing Record 50 of Set 6 | beneditinos
# ------ break for 10 seconds ------
# Processing Record 1 of Set 7 | hammerfest
# Processing Record 2 of Set 7 | worthington
# Processing Record 3 of Set 7 | port augusta
# Processing Record 4 of Set 7 | alugan
# Processing Record 5 of Set 7 | moron
# Processing Record 6 of Set 7 | tocopilla
# City not found. Skipping...
# Processing Record 7 of Set 7 | makokou
# Processing Record 8 of Set 7 | miyako
# Processing Record 9 of Set 7 | kristinehamn
# City not found. Skipping...
# Processing Record 10 of Set 7 | chojnow
# Processing Record 11 of Set 7 | mount gambier
# City not found. Skipping...
# Processing Record 12 of Set 7 | ilinskiy
# Processing Record 13 of Set 7 | belyy yar
# City not found. Skipping...
# Processing Record 14 of Set 7 | thatta
# Processing Record 15 of Set 7 | chaohu
# Processing Record 16 of Set 7 | bathsheba
# Processing Record 17 of Set 7 | santa cruz
# Processing Record 18 of Set 7 | salalah
# Processing Record 19 of Set 7 | hamilton
# Processing Record 20 of Set 7 | vila velha
# Processing Record 21 of Set 7 | trairi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 22 of Set 7 | zharkent
# Processing Record 23 of Set 7 | camden
# Processing Record 24 of Set 7 | ponta delgada
# Processing Record 25 of Set 7 | sinnamary
# Processing Record 26 of Set 7 | kieta
# Processing Record 27 of Set 7 | port keats
# Processing Record 28 of Set 7 | kuching
# City not found. Skipping...
# Processing Record 29 of Set 7 | mineiros
# Processing Record 30 of Set 7 | ngunguru
# Processing Record 31 of Set 7 | oktyabrskiy
# Processing Record 32 of Set 7 | mayo
# Processing Record 33 of Set 7 | nizhniy mamon
# Processing Record 34 of Set 7 | almaznyy
# Processing Record 35 of Set 7 | russell
# City not found. Skipping...
# Processing Record 36 of Set 7 | mehamn
# Processing Record 37 of Set 7 | nanakuli
# Processing Record 38 of Set 7 | hofn
# Processing Record 39 of Set 7 | concordia
# Processing Record 40 of Set 7 | hualmay
# Processing Record 41 of Set 7 | riverton
# Processing Record 42 of Set 7 | roswell
# Processing Record 43 of Set 7 | iqaluit
# Processing Record 44 of Set 7 | aksarka
# Processing Record 45 of Set 7 | coffs harbour
# Processing Record 46 of Set 7 | trelew
# Processing Record 47 of Set 7 | suez
# Processing Record 48 of Set 7 | marzuq
# Processing Record 49 of Set 7 | grande prairie
# Processing Record 50 of Set 7 | victor harbor
# ------ break for 10 seconds ------
# Processing Record 1 of Set 8 | pundaguitan
# Processing Record 2 of Set 8 | chernyshevsk
# Processing Record 3 of Set 8 | luanda
# Processing Record 4 of Set 8 | noshiro
# Processing Record 5 of Set 8 | luganville
# Processing Record 6 of Set 8 | chibombo
# Processing Record 7 of Set 8 | yanji
# Processing Record 8 of Set 8 | falmouth
# Processing Record 9 of Set 8 | hatta
# Processing Record 10 of Set 8 | las palmas
# Processing Record 11 of Set 8 | pacific grove
# Processing Record 12 of Set 8 | maltahohe
# Processing Record 13 of Set 8 | markova
# Processing Record 14 of Set 8 | san policarpo
# City not found. Skipping...
# Processing Record 15 of Set 8 | byron bay
# Processing Record 16 of Set 8 | aguimes
# Processing Record 17 of Set 8 | tarime
# Processing Record 18 of Set 8 | northam
# Processing Record 19 of Set 8 | grafton
# Processing Record 20 of Set 8 | nuziders
# Processing Record 21 of Set 8 | dingle
# Processing Record 22 of Set 8 | nyurba
# City not found. Skipping...
# Processing Record 23 of Set 8 | oktyabrskoye
# Processing Record 24 of Set 8 | nanning
# Processing Record 25 of Set 8 | mae hong son
# Processing Record 26 of Set 8 | bahia blanca
# Processing Record 27 of Set 8 | neryungri
# Processing Record 28 of Set 8 | bourg-en-bresse
# Processing Record 29 of Set 8 | saint-augustin
# Processing Record 30 of Set 8 | umm lajj
# Processing Record 31 of Set 8 | ozark
# Processing Record 32 of Set 8 | cabinda
# City not found. Skipping...
# Processing Record 33 of Set 8 | port hedland
# Processing Record 34 of Set 8 | valteron
# Processing Record 35 of Set 8 | san matias
# Processing Record 36 of Set 8 | algeciras
# Processing Record 37 of Set 8 | grevesmuhlen
# Processing Record 38 of Set 8 | novoagansk
# Processing Record 39 of Set 8 | labuhan
# Processing Record 40 of Set 8 | marsaxlokk
# Processing Record 41 of Set 8 | samarai
# Processing Record 42 of Set 8 | kindu
# Processing Record 43 of Set 8 | bestobe
# Processing Record 44 of Set 8 | tuscaloosa
# Processing Record 45 of Set 8 | half moon bay
# Processing Record 46 of Set 8 | okakarara
# Processing Record 47 of Set 8 | beian
# Processing Record 48 of Set 8 | dayong
# Processing Record 49 of Set 8 | port-gentil
# Processing Record 50 of Set 8 | mananjary
# ------ break for 10 seconds ------
# Processing Record 1 of Set 9 | the valley
# Processing Record 2 of Set 9 | formosa do rio preto
# Processing Record 3 of Set 9 | makakilo city
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 9 | la pintada
# Processing Record 5 of Set 9 | valea crisului
# Processing Record 6 of Set 9 | kanniyakumari
# Processing Record 7 of Set 9 | benemerito de las americas
# Processing Record 8 of Set 9 | naliya
# Processing Record 9 of Set 9 | parana
# City not found. Skipping...
# Processing Record 10 of Set 9 | misratah
# Processing Record 11 of Set 9 | sulangan
# Processing Record 12 of Set 9 | cap malheureux
# Processing Record 13 of Set 9 | killybegs
# Processing Record 14 of Set 9 | cidreira
# Processing Record 15 of Set 9 | maumere
# City not found. Skipping...
# Processing Record 16 of Set 9 | hasilpur
# Processing Record 17 of Set 9 | betsiamites
# Processing Record 18 of Set 9 | yertsevo
# Processing Record 19 of Set 9 | sulingen
# Processing Record 20 of Set 9 | taltal
# Processing Record 21 of Set 9 | tondano
# Processing Record 22 of Set 9 | astoria
# City not found. Skipping...
# Processing Record 23 of Set 9 | tura
# Processing Record 24 of Set 9 | clyde river
# Processing Record 25 of Set 9 | nanortalik
# Processing Record 26 of Set 9 | fernandez
# Processing Record 27 of Set 9 | minas
# Processing Record 28 of Set 9 | moree
# Processing Record 29 of Set 9 | alofi
# Processing Record 30 of Set 9 | stjordalshalsen
# Processing Record 31 of Set 9 | mahon
# Processing Record 32 of Set 9 | astana
# Processing Record 33 of Set 9 | maragogi
# Processing Record 34 of Set 9 | verkhnyaya maksakovka
# Processing Record 35 of Set 9 | mathathane
# Processing Record 36 of Set 9 | taylor
# Processing Record 37 of Set 9 | voi
# Processing Record 38 of Set 9 | sao felix do xingu
# Processing Record 39 of Set 9 | khani
# Processing Record 40 of Set 9 | mezen
# Processing Record 41 of Set 9 | pula
# Processing Record 42 of Set 9 | tucurui
# Processing Record 43 of Set 9 | nuuk
# Processing Record 44 of Set 9 | etchoropo
# City not found. Skipping...
# Processing Record 45 of Set 9 | havre de grace
# Processing Record 46 of Set 9 | idaho falls
# Processing Record 47 of Set 9 | ust-nera
# Processing Record 48 of Set 9 | colares
# Processing Record 49 of Set 9 | zonguldak
# Processing Record 50 of Set 9 | syracuse
# ------ break for 10 seconds ------
# Processing Record 1 of Set 10 | filadelfia
# Processing Record 2 of Set 10 | chittaurgarh
# Processing Record 3 of Set 10 | floro
# Processing Record 4 of Set 10 | la fleche
# City not found. Skipping...
# Processing Record 5 of Set 10 | ennis
# Processing Record 6 of Set 10 | yumen
# Processing Record 7 of Set 10 | sompeta
# Processing Record 8 of Set 10 | yulara
# Processing Record 9 of Set 10 | fortuna
# City not found. Skipping...
# Processing Record 10 of Set 10 | sambava
# Processing Record 11 of Set 10 | vao
# Processing Record 12 of Set 10 | matadi
# Processing Record 13 of Set 10 | imeni poliny osipenko
# Processing Record 14 of Set 10 | fairlie
# Processing Record 15 of Set 10 | kortkeros
# Processing Record 16 of Set 10 | aykhal
# Processing Record 17 of Set 10 | fairbanks
# Processing Record 18 of Set 10 | connersville
# Processing Record 19 of Set 10 | bahia de caraquez
# Processing Record 20 of Set 10 | obukhiv
# Processing Record 21 of Set 10 | curup
# Processing Record 22 of Set 10 | kirakira
# City not found. Skipping...
# Processing Record 23 of Set 10 | tam ky
# Processing Record 24 of Set 10 | piacabucu
# Processing Record 25 of Set 10 | port macquarie
# Processing Record 26 of Set 10 | melenci
# Processing Record 27 of Set 10 | bilibino
# Processing Record 28 of Set 10 | cape canaveral
# Processing Record 29 of Set 10 | paita
# Processing Record 30 of Set 10 | sabha
# Processing Record 31 of Set 10 | aguada de pasajeros
# Processing Record 32 of Set 10 | hasanabad
# Processing Record 33 of Set 10 | tazovskiy
# City not found. Skipping...
# Processing Record 34 of Set 10 | cedar city
# Processing Record 35 of Set 10 | caravelas
# Processing Record 36 of Set 10 | portland
# Processing Record 37 of Set 10 | brokopondo
# Processing Record 38 of Set 10 | quatre cocos
# Processing Record 39 of Set 10 | montrose
# Processing Record 40 of Set 10 | jiayuguan
# Processing Record 41 of Set 10 | katangli
# Processing Record 42 of Set 10 | koumac
# City not found. Skipping...
# Processing Record 43 of Set 10 | aitape
# Processing Record 44 of Set 10 | galesong
# Processing Record 45 of Set 10 | carauari
# City not found. Skipping...
# Processing Record 46 of Set 10 | ayan
# Processing Record 47 of Set 10 | la rioja
# City not found. Skipping...
# Processing Record 48 of Set 10 | dong xoai
# Processing Record 49 of Set 10 | takab
# Processing Record 50 of Set 10 | geneva
# ------ break for 10 seconds ------
# Processing Record 1 of Set 11 | karratha
# Processing Record 2 of Set 11 | ajdabiya
# Processing Record 3 of Set 11 | san ignacio
# Processing Record 4 of Set 11 | bera
# City not found. Skipping...
# Processing Record 5 of Set 11 | urambo
# Processing Record 6 of Set 11 | tulum
# Processing Record 7 of Set 11 | dundee
# City not found. Skipping...
# Processing Record 8 of Set 11 | cairns
# Processing Record 9 of Set 11 | lebedyn
# Processing Record 10 of Set 11 | te anau
# Processing Record 11 of Set 11 | gouyave
# Processing Record 12 of Set 11 | bontang
# Processing Record 13 of Set 11 | saint-joseph
# Processing Record 14 of Set 11 | riyadh
# Processing Record 15 of Set 11 | marsala
# Processing Record 16 of Set 11 | zhuanghe
# Processing Record 17 of Set 11 | muisne
# City not found. Skipping...
# Processing Record 18 of Set 11 | taoudenni
# Processing Record 19 of Set 11 | wuan
# Processing Record 20 of Set 11 | bon accord
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 21 of Set 11 | chichester
# Processing Record 22 of Set 11 | shimoda
# Processing Record 23 of Set 11 | urucara
# Processing Record 24 of Set 11 | chernyshevskiy
# Processing Record 25 of Set 11 | saint-pierre
# Processing Record 26 of Set 11 | jvari
# Processing Record 27 of Set 11 | pitkyaranta
# Processing Record 28 of Set 11 | freeport
# Processing Record 29 of Set 11 | namibe
# Processing Record 30 of Set 11 | acapulco
# Processing Record 31 of Set 11 | hit
# Processing Record 32 of Set 11 | nativitas
# Processing Record 33 of Set 11 | ha giang
# City not found. Skipping...
# Processing Record 34 of Set 11 | tateyama
# Processing Record 35 of Set 11 | le vauclin
# Processing Record 36 of Set 11 | phalaborwa
# Processing Record 37 of Set 11 | mikkeli
# Processing Record 38 of Set 11 | gaoua
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({
    'City': name,
    'Cloudiness': cloud,
    'Country': country,
    'Date': date,
    'Humidity': humid,
    'Lat': lat,
    'Lng': lon,
    'Max Temp': maxTemp,
    'Wind Speed': wind
})
weather_df.to_csv(output_data_file)
weather_df.count()
# Out:
# City          538
# Cloudiness    538
# Country       538
# Date          538
# Humidity      538
# Lat           538
# Lng           538
# Max Temp      538
# Wind Speed    538
# dtype: int64

# %%
weather_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Khatassy          40      RU  1562530589        67  61.91  129.64
# 1    Zhigansk         100      RU  1562530589        96  66.77  123.37
# 2       Bluff         100      AU  1562530589        80 -23.58  149.07
# 3     Ushuaia           0      AR  1562530504        92 -54.81  -68.31
# 4  Bredasdorp          67      ZA  1562530590        76 -34.53   20.04
#
#    Max Temp  Wind Speed
# 0      16.0        3.00
# 1      11.5        4.30
# 2      16.0        5.44
# 3       2.0        3.10
# 4      15.0        2.60

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Max Temp'], marker = 'o', alpha = 0.75, edgecolors = 'black')
plt.title('City Latitude vs. Max Temperature (07/07/19)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid()
plt.savefig()
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Humidity'], marker = 'o', alpha = 0.75, edgecolors = 'black')
plt.title('City Latitude vs. Humidity (07/07/19)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
